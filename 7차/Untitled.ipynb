# %%
# !pip install parse
# Out:
# ...
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24581 sha256=cdd14bc48e3a5c06d28993255844ee77d2adf4f2fabf9b535cfc328cf75f14fb
#   Stored in directory: c:\users\jbrig\appdata\local\pip\cache\wheels\d6\9c\58\ee3ba36897e890f3ad81e9b730791a153fce20caa4a8a474df
# Successfully built parse
# ...

# %%
from urllib import parse

# %%
key = '9PmfqszexvqJNyi6mxeF3Xxa%2FOu0A40dDOQLPnGqc1TlmV3coJ8BpeW438mUQW3fDbx2oASf1OQP7zYdQLsu6g%3D%3D'
key = parse.urlencode({'ex' :key})

key
# Out:
# 'ex=9PmfqszexvqJNyi6mxeF3Xxa%252FOu0A40dDOQLPnGqc1TlmV3coJ8BpeW438mUQW3fDbx2oASf1OQP7zYdQLsu6g%253D%253D'
