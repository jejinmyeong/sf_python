# %%
from urllib import request, urlencode

url = 'http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19SidoInfStateJson'
queryParams = '3zNZ%2BuF%2F5jMsu2Hnx9VAGKJYTwrIYPJs1f%2BnhjhogsBEb9SjDxUOaViV7ruh11i4pu4m6HuCyt9MB34M2Zgc4Q%3D%3D/3zNZ+uF/5jMsu2Hnx9VAGKJYTwrIYPJs1f+nhjhogsBEb9SjDxUOaViV7ruh11i4pu4m6HuCyt9MB34M2Zgc4Q==' + urlencode({ quote_plus('ServiceKey') : '서비스키', quote_plus('pageNo') : '1', quote_plus('numOfRows') : '10', quote_plus('startCreateDt') : '20200410', quote_plus('endCreateDt') : '20200410' })

request = requests(url + queryParams)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
print (response_body)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-22-5c28ccfec58a> in <module>
# ----> 1 from urllib import request, urlencode
#       2
#       3 url = 'http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19SidoInfStateJson'
#       4 queryParams = '3zNZ%2BuF%2F5jMsu2Hnx9VAGKJYTwrIYPJs1f%2BnhjhogsBEb9SjDxUOaViV7ruh11i4pu4m6HuCyt9MB34M2Zgc4Q%3D%3D/3zNZ+uF/5jMsu2Hnx9VAGKJYTwrIYPJs1f+nhjhogsBEb9SjDxUOaViV7ruh11i4pu4m6HuCyt9MB34M2Zgc4Q==' + urlencode({ quote_plus('ServiceKey') : '서비스키', quote_plus('pageNo') : '1', quote_plus('numOfRows') : '10', quote_plus('startCreateDt') : '20200410', quote_plus('endCreateDt') : '20200410' })
#       5
#
# ImportError: cannot import name 'urlencode' from 'urllib' (C:\Users\jbrig\anaconda3\envs\test\lib\urllib\__init__.py)
