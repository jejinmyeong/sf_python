# %% [markdown]
# ## Pandas
# Pandas는 다음과 같은 특징을 같습니다.
# - NumPy를 내부적으로 활용함(NumPy의 특징을 그대로 가짐)
# - 데이터분석에 특화된 데이터 구조 제공
# - 다양한 데이터 분석 함수 제공
# - 데이터베이스에 쉽게 연결 가능
#
# ### 판다스의 주요 구성 요소-DataFame, Series, Index
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1. DataFrame
#
# - 2차원 데이터 구조
# - 일반적으로 df로 이름 붙임
# - 엑셀 스프레드시트, 데이터베이스등과 동일한 2차원 구조
# - 가장 많이 활용하게될 구조
# - Series가 합쳐진 형태
# > pd.Dataframe()으로 생성 <br>
# > 딕셔너리 또는 리스트를 통해 데이터프레임을 만들 수 있다.
# ### 속성
#
# 아래와 같은 속성을 가집니다.
#
# - index
# - columns
# - values

# %% [markdown]
# ### * DataFrame 생성
# > - pd.Dataframe()으로 생성 <br>
# > - 딕셔너리 또는 리스트를 통해 데이터프레임을 만들 수 있다.

# %%
import pandas as pd

# %%
#딕셔너리로 데이터프레임 생성
df1=pd.DataFrame({'이름':['홍길동','이길동','강일동','박길동'],
                  '나이':[30,45,66,33],
                  '점수':[55,77,85,33]
   
})
df1
# Out:
#     이름  나이  점수
# 0  홍길동  30  55
# 1  이길동  45  77
# 2  강일동  66  85
# 3  박길동  33  33

# %%
#리스트로 데이터프레임 생성 (1) : 컬럼명없이 생성
df2=pd.DataFrame([['홍길동',30,'강원도'],
                 ['김하늘',40,'서울'],
                 ['이두리',30,'인천']])
df2
# Out:
#      0   1    2
# 0  홍길동  30  강원도
# 1  김하늘  40   서울
# 2  이두리  30   인천

# %%
#리스트로 데이터프레임 생성 (1) : 컬럼명 지정 생성
df2=pd.DataFrame([['홍길동',30,'강원도'],
                 ['김하늘',40,'서울'],
                 ['이두리',30,'인천']], columns=['성명','나이','지역'])
df2
# Out:
#     성명  나이   지역
# 0  홍길동  30  강원도
# 1  김하늘  40   서울
# 2  이두리  30   인천

# %%
#[참고] 데이터 프레임 행열 바꾸기 df2.T
df2.T
# Out:
#       0    1    2
# 성명  홍길동  김하늘  이두리
# 나이   30   40   30
# 지역  강원도   서울   인천

# %%
# typoe() 확인
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ###  * DataFrame 속성
# > - index
# > - coumns
# > - values

# %%
# index확인
print(df1.index)
print(df2.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)
# RangeIndex(start=0, stop=3, step=1)

# %%
# columns확인
print(df1.columns)
print(df2.columns)
# Out:
# Index(['이름', '나이', '점수'], dtype='object')
# Index(['성명', '나이', '지역'], dtype='object')

# %%
#columns index로 인덱싱
print(df1.columns[2])

df1.columns[2]='성적'
# Out:
# 점수
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-4a7e2994eafd> in <module>
#       2 print(df1.columns[2])
#       3
# ----> 4 df1.columns[2]='성적'
#
# ~\.conda\envs\mh\lib\site-packages\pandas\core\indexes\base.py in __setitem__(self, key, value)
#    4275     @final
#    4276     def __setitem__(self, key, value):
# -> 4277         raise TypeError("Index does not support mutable operations")
#    4278
#    4279     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
#columns변경
print(df1.columns)
df1.columns=['성명','나이','성적']
df1
# Out:
# Index(['이름', '나이', '점수'], dtype='object')
#     성명  나이  성적
# 0  홍길동  30  55
# 1  이길동  45  77
# 2  강일동  66  85
# 3  박길동  33  33

# %%
#values 확인
df1.values
# Out:
# array([['강남구', 3238, 1292, 430, 584, 932],
#        ['강동구', 1010, 379, 99, 155, 377],
#        ['강북구', 831, 369, 120, 138, 204],
#        ['강서구', 911, 388, 258, 184, 81],
#        ['관악구', 2109, 846, 260, 390, 613],
#        ['광진구', 878, 573, 78, 53, 174],
#        ['구로구', 1884, 1142, 173, 246, 323],
#        ['금천구', 1348, 674, 51, 269, 354],
#        ['노원구', 1566, 542, 57, 451, 516],
#        ['도봉구', 825, 238, 159, 42, 386],
#        ['동대문구', 1870, 1070, 23, 198, 579],
#        ['동작구', 1302, 544, 341, 103, 314],
#        ['마포구', 980, 314, 118, 169, 379],
#        ['서대문구', 1254, 844, 50, 68, 292],
#        ['서초구', 2297, 1406, 157, 336, 398],
#        ['성동구', 1327, 730, 91, 241, 265],
#        ['성북구', 1651, 1009, 78, 360, 204],
#        ['송파구', 1081, 529, 21, 68, 463],
#        ['양천구', 2482, 1843, 142, 30, 467],
#        ['영등포구', 1277, 495, 214, 195, 373],
#        ['용산구', 2096, 1368, 218, 112, 398],
#        ['은평구', 2108, 1138, 224, 278, 468],
# ...

# %% [markdown]
# ### 2. 외부 파일 읽기
# * pd.read_csv('파일명')
# * pd.read_excel('파일명')
#
#
# ### 3. 외부 파일 저장하기
# * 데이터프레임.to_csv('파일명')
# * 데이터프레임.to_excel('파일명')

# %%
#'./data/sample.csv' 파일 읽기
df=pd.read_csv('./data/sample.csv')
df
# Out:
#    bun name  kor  eng bigo
# 0    1   aa   70   68  NaN
# 1    2   bb   85   88  NaN
# 2    3   cc   96   92  Yes
# 3    4   dd   48   37   No
# 4    5   ee   85   79  NaN
# 5    6   ff   88   88  NaN
# 6    7   gg   57   55   No
# 7    8   hh   72   79  NaN

# %%
# './data/sample1.csv' 데이터 읽어오기
df2=pd.read_csv('./data/sample1.csv',encoding='euc-kr')
df2
# Out:
#    번호  이름  국어  영어     비고
# 0   1  aa  70  68    NaN
# 1   2  bb  85  88    NaN
# 2   3  cc  96  92  성적우수자
# 3   4  dd  48  37    재수강
# 4   5  ee  85  79    NaN
# 5   6  ff  88  88    NaN
# 6   7  gg  57  55    재수강
# 7   8  hh  72  79    NaN

# %% [markdown]
# ## 4. 데이터 탐색
# 1.  %pwd : 현재 작업폴더 확인:
# 2. ls :현재 폴더 내용확인
# 3. df.shape : (데이터 규모확인)데이터프레임의 행,열 갯수 확인
# 4. df.head() : 위에서 5개 데이터 보여줌 df.head(10)-> 위에서 10개 보여줌
# 5. df.tail()  : 아래의 5개 데이터 보여줌 df.tail10)->아래에서 10개 보여줌
# 6. df.sample(5) : 랜덤으로 5개 데이터를 보여줌
# 8. df.info() : 데이터프레임의 각 열에 대한 데이터 형의 정보를 확인할 수 있다.
# 9. df.dtypes :데이터프레임의 각 열에 대한 데이터 형만 확인할 수 있다.
# 10. df.describe() : 숫자 데이터를 기술통계로 요약할 수 있음(갯수,평균,표춘편차,최소값, 최대값, 사분의 수 확인)
# 11. df.describe(include=[object]) #object값을 요약해서 본다.
# 12. df.열이름.vlaue_counts() : 열이름별로 데이터가 몇 개 있는지 확인함
#
# 13. df.isnull().sum() : 결측치 어느 정도 있는지 확인함

# %%
df1=pd.read_csv('./data/cctv_in_seoul.csv')
df1.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %% [markdown]
# ## 5. 데이터 Selection 및 필터링
# #### 1)  [ ] : 컬럼 기반 필터링 또는 불린 인덱싱 필터링 제공
# #### 2)  .loc[ ]: 명칭(이름)기반 인덱싱
# #### 3)  .iloc[ ]: index(위치)기반 인덱싱
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### * column 선택하기
#   - 기본적으로 [ ]는 column을 추출
#   - 컬럼 인덱스일 경우 인덱스의 리스트 사용 가능
#     - 리스트를 전달할 경우 결과는 Dataframe
#     - 하나의 컬럼명을 전달할 경우 결과는 Series

# %%
# 하나의 컬럼 확인하기 
'''
------------------------------------------------
   df['컬럼명']
------------------------------------------------
'''

df1['기관명']
# Out:
# 0      강남구
# 1      강동구
# 2      강북구
# 3      강서구
# 4      관악구
# 5      광진구
# 6      구로구
# 7      금천구
# 8      노원구
# 9      도봉구
# 10    동대문구
# 11     동작구
# 12     마포구
# 13    서대문구
# 14     서초구
# 15     성동구
# 16     성북구
# 17     송파구
# 18     양천구
# 19    영등포구
# 20     용산구
# 21     은평구
# 22     종로구
# 23      중구
# 24     중랑구
# Name: 기관명, dtype: object

# %%
# 복수의 컬럼 선택하기
------------------------------------------------
   df[['컬럼명1','컬럼명2'...]]
------------------------------------------------
'''

# %%
df1.columns
# Out:
# Index(['기관명', '소계', '2013년도 이전', '2014년', '2015년', '2016년'], dtype='object')

# %%
df1[['2014년','2016년']]
# Out:
#     2014년  2016년
# 0     430    932
# 1      99    377
# 2     120    204
# 3     258     81
# 4     260    613
# 5      78    174
# 6     173    323
# 7      51    354
# 8      57    516
# 9     159    386
# 10     23    579
# 11    341    314
# 12    118    379
# 13     50    292
# 14    157    398
# 15     91    265
# 16     78    204
# 17     21    463
# 18    142    467
# 19    214    373
# 20    218    398
# 21    224    468
# 22    314    630
# 23    190    348
# 24    121    109

# %% [markdown]
# ### * Row 선택하기

# %% [markdown]
# #### [ ]
#   - dataframe의 경우 기본적으로 [] 연산자가 **column 선택**에 사용
#   - 하지만, slicing은 row 레벨로 지원
#   - 불릿 인덱싱 필터링

# %%
# 행 인덱싱
df1[:3]
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204

# %%
#df1[0:3]
df1[0:3]
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204

# %% [markdown]
# ### .loc[ ] : 명칭 기반 인덱싱 및 슬라이싱

# %%
df1.head(3)
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204

# %%
# 행 하나
df1.loc[2]
# Out:
# 기관명          강북구
# 소계           831
# 2013년도 이전    369
# 2014년        120
# 2015년        138
# 2016년        204
# Name: 2, dtype: object

# %%
#복수 행
df1.loc[[2,3,5]]
# Out:
#    기관명   소계  2013년도 이전  2014년  2015년  2016년
# 2  강북구  831        369    120    138    204
# 3  강서구  911        388    258    184     81
# 5  광진구  878        573     78     53    174

# %%
# 슬라이싱
df1.loc[1:4]
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %%
# 행, 열 접근
df1.loc[3,'소계']
# Out:
# 911

# %%
# 복수 행, 열 접근
df1.loc[[1,2,5],['기관명','2014년']]
# Out:
#    기관명  2014년
# 1  강동구     99
# 2  강북구    120
# 5  광진구     78

# %%
# 행,열 슬라이싱
df1.loc[1:4,'2014년':]
# Out:
#    2014년  2015년  2016년
# 1     99    155    377
# 2    120    138    204
# 3    258    184     81
# 4    260    390    613

# %%
# '기관명'을 index명으로 변경 (df1.set_inex('기관명'))
df1_=df1.set_index('기관명')
df1_
# Out:
#         소계  2013년도 이전  2014년  2015년  2016년
# 기관명
# 강남구   3238       1292    430    584    932
# 강동구   1010        379     99    155    377
# 강북구    831        369    120    138    204
# 강서구    911        388    258    184     81
# 관악구   2109        846    260    390    613
# 광진구    878        573     78     53    174
# 구로구   1884       1142    173    246    323
# 금천구   1348        674     51    269    354
# 노원구   1566        542     57    451    516
# 도봉구    825        238    159     42    386
# 동대문구  1870       1070     23    198    579
# 동작구   1302        544    341    103    314
# 마포구    980        314    118    169    379
# 서대문구  1254        844     50     68    292
# 서초구   2297       1406    157    336    398
# 성동구   1327        730     91    241    265
# 성북구   1651       1009     78    360    204
# 송파구   1081        529     21     68    463
# 양천구   2482       1843    142     30    467
# 영등포구  1277        495    214    195    373
# 용산구   2096       1368    218    112    398
# ...

# %%
df1_.loc['은평구':'중구',['2014년','2016년']]
# Out:
#      2014년  2016년
# 기관명
# 은평구    224    468
# 종로구    314    630
# 중구     190    348

# %%
df1_.loc['은평구':,'2015년':]
# Out:
#      2015년  2016년
# 기관명
# 은평구    278    468
# 종로구    211    630
# 중구      72    348
# 중랑구    177    109

# %% [markdown]
# ### .iloc[ ] : index 기반 인덱싱 및 슬라이싱

# %%
df1.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %%
# 하나 행
df1.iloc[2]
# Out:
# 기관명          강북구
# 소계           831
# 2013년도 이전    369
# 2014년        120
# 2015년        138
# 2016년        204
# Name: 2, dtype: object

# %%
#복수 행
df1.iloc[[2,3,4]]
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %%
# 슬라이싱
df1.iloc[1:4]
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81

# %%
# 행, 열 접근
df1.iloc[2,2]
# Out:
# 369

# %%
# 복수 행,열 접근
df1.iloc[[1,3,5],[0,1,-1]]
# Out:
#    기관명    소계  2016년
# 1  강동구  1010    377
# 3  강서구   911     81
# 5  광진구   878    174

# %%
# 행, 열 슬라이승
df1.iloc[:3,-3:]
# Out:
#    2014년  2015년  2016년
# 0    430    584    932
# 1     99    155    377
# 2    120    138    204

# %% [markdown]
# ### boolean selection row 선택

# %%
df1.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %%
# 조건에 만족하는 행 전체 보기
# 2016년에 292보다 큰 데이터
df1[df1['2016년']>292]
# Out:
#      기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  3238       1292    430    584    932
# 1    강동구  1010        379     99    155    377
# 4    관악구  2109        846    260    390    613
# 6    구로구  1884       1142    173    246    323
# 7    금천구  1348        674     51    269    354
# 8    노원구  1566        542     57    451    516
# 9    도봉구   825        238    159     42    386
# 10  동대문구  1870       1070     23    198    579
# 11   동작구  1302        544    341    103    314
# 12   마포구   980        314    118    169    379
# 14   서초구  2297       1406    157    336    398
# 17   송파구  1081        529     21     68    463
# 18   양천구  2482       1843    142     30    467
# 19  영등포구  1277        495    214    195    373
# 20   용산구  2096       1368    218    112    398
# 21   은평구  2108       1138    224    278    468
# 22   종로구  1619        464    314    211    630
# 23    중구  1023        413    190     72    348

# %%
# 조건이 여러개 일 때 : &(and),  | (or)
cond1=df1['2015년']>=200
cond2=df1['2016년']>=200
df1[cond1 & cond2]
# Out:
#     기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0   강남구  3238       1292    430    584    932
# 4   관악구  2109        846    260    390    613
# 6   구로구  1884       1142    173    246    323
# 7   금천구  1348        674     51    269    354
# 8   노원구  1566        542     57    451    516
# 14  서초구  2297       1406    157    336    398
# 15  성동구  1327        730     91    241    265
# 16  성북구  1651       1009     78    360    204
# 21  은평구  2108       1138    224    278    468
# 22  종로구  1619        464    314    211    630

# %%
# 조건에 만족하는 행, 열 :
df1[df1['2016년']>=500][['기관명','2016년']]
# Out:
#      기관명  2016년
# 0    강남구    932
# 4    관악구    613
# 8    노원구    516
# 10  동대문구    579
# 22   종로구    630

# %%
# 특정 문자가 포함된 열 추출
#df['열이름'].str,contains('찾는 문자')

df1[df1['기관명'].str.contains('강')]
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81

# %%
# isin 함수 활용
df1[df1['기관명'].isin(['강남구','강동구','강서구'])]
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 3  강서구   911        388    258    184     81

# %% [markdown]
# ### 정렬
# > df.sort_index()<br>
# > df.sort_values('열이름')

# %%
df1.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %%
df1.sort_values('소계',ascending=False, inplace=True)
display(df1.head())
# Out:
#     기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0   강남구  3238       1292    430    584    932
# 18  양천구  2482       1843    142     30    467
# 14  서초구  2297       1406    157    336    398
# 4   관악구  2109        846    260    390    613
# 21  은평구  2108       1138    224    278    468

# %%
df1.sort_index(inplace=True)
df1.head(3)
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
